# %% [markdown]
# # 準備

# %%
# !pip install gensim
# !pip install SudachiPy==0.5.4 ginza==4.0.6 ja-ginza==4.0.0 
# !pip install pytorch_lightning
# # !pip install emoji
# !pip install transformers[ja]
# !pip install sentencepiece

# !pip install fugashi
# !pip install ipadic

# !pip install deep_translator
# !pip install googletrans==4.0.0-rc1

# %% [markdown]
# # import

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers
import os
import re
import matplotlib.pyplot as plt
from glob import glob
# %matplotlib inline

#one_hotベクトル
from sklearn.feature_extraction.text import TfidfVectorizer

#ベクトル化
from gensim.models import word2vec

#データ分割用
from sklearn.model_selection import train_test_split
from sklearn.manifold import TSNE
import sklearn

import torch

from transformers import AutoTokenizer
from transformers import BertJapaneseTokenizer, AutoModelForMaskedLM, BertModel

# 翻訳
# -*- coding: utf-8
from googletrans import Translator

# %% [markdown]
# # データの読み込み

# %%
files = glob("*.xlsx")
files
# Out:
# ['vocal_商品性情報.xlsx', '類似データ.xlsx', 'tqnet情報.xlsx']

# %%
vocal_xlsx = files[0]
tqnet_xlsx = files[2]

vocal_df = pd.read_excel(vocal_xlsx)
tqnet_df = pd.read_excel(tqnet_xlsx)

vocal_df = vocal_df[['time', 'Unnamed: 1', 'Unnamed: 2']]
vocal_df.columns = ["time", "text", "car_name"]

tqnet_df.columns = ["car_name", "text"]

# %%
tqnet_df
# vocal_df
# Out:
#   car_name                                               text
# 0     ｼｴﾝﾀ  運転席に乗り込み内側からドアを閉めようとすると、手をかける場所が 上のほうにあるので非常に閉...
# 1     ﾙｰﾐｰ         走行中、加速した時エンジンの音が大きく感じて、段差などの時、カラカラと金属音がする。
# 2       ﾉｱ  シフトノブ部分の下側に隙間があり小銭などが入ってしまったら取れなくなってしまう。実際にほかの...
# 3     ｸﾗｳﾝ                        トランクを開けるスイッチの場所がわかりずらく押しにくい
# 4     RAV4  運転席、助手席のドア取っ手が前寄りについているためドアを閉めるのが重い、強風が吹いたと\nき...
# 5        a  運転席のドアが閉めづらい 運転席のドア内側の手をかける部分が高い位置の為ドアを閉めづらいそう...
# 6        b  運転席のドアが閉めづらい 運転席のドア内側の手をかける部分が高い位置の為ドアを閉めづらいそう...
# 7        c   運転席ドアが閉めづらい 運転席のドア内側の手をかける部分が高い位置の為ドアを閉めづらいそうです。

# %% [markdown]
# # データクリーニング
# ## vocal (X)

# %%
vocal_df["text"] = vocal_df["text"].str.replace("\n", ' ')
vocal_df["text"] = vocal_df["text"].str.replace(re.compile("（\w+）"), '')
vocal_df["text"] = vocal_df["text"].str.replace(re.compile("[。、]"), ' ')
vocal_df = vocal_df.iloc[0:100, :]
vocal_df.head(16)
# Out:
#                    time                                               text  \
# 0   2022-12-26 00:00:00  運転席のドアが閉めづらい 運転席のドア内側の手をかける部分が高い位置の為ドアを閉めづらいそう...
# 1   2022-12-22 00:00:00  シフトノブ付近の小物入れが使いづらい シフトノブをパーキングに入れているとき小物入れとシフト...
# 2   2022-12-22 00:00:00  助手席側のドアパネルとグローブボックスの位置が近い 助手席側のドア下のポケットに厚手の物入れ...
# 3   2022-12-22 00:00:00  加速時のエンジン音が大きい アクセルを深く踏んだ時のエンジン音が大きい 特に力強く加速した際...
# 4   2022-12-22 00:00:00  バックドアの開閉操作がやや使いづらい バックドアが開く時に上から手で押すとその位置で止まるが...
# 5   2022-12-22 00:00:00  運転席　助手席降りる時開閉しづらい フロントドアトリムボードのドアノブの位置が高すぎて開閉し...
# 6   2022-12-21 00:00:00  トランクを開けるスイッチの位置がわかりにくい  トランクを外から開けるスイッチの位置が車の中...
# 7   2022-12-17 00:00:00  メータ下にカードが入ってしまう  メータの所にカードを置いたら下に入って取れなくなった  物...
# 8   2022-12-03 00:00:00  シフトノブ部に物を落としてしまいそうな位隙間がある  シフトポジションをPレンジにした時にシ...
# 9   2022-11-30 00:00:00  バックドアが重くて開けにくい 買い物帰りに荷物を積む時 バックドアが重くて大変とのご指摘を受...
# 10  2022-11-30 00:00:00  バックドアが思っているよりかなり軽い バックドアが思いのほか軽く 空いた瞬間に体を避ける事に...
# 11  2022-11-30 00:00:00  運転席のドアを室内から開けた時に掴まるところがドアハンドルより上にある為掴みにくい 室内から...
# 12  2022-12-01 00:00:00                                                テスト
# 13  2022-12-02 00:00:00  ナビ左下側のナビパネルにある ボリューム調整ダイアルの遊びが大きいのが気になる  音量が少し...
# 14                    s  運転席　助手席降りる時開閉しづらい フロントドアトリムボードのドアノブの位置が高すぎて開閉し...
#
#    car_name
# 0      シエンタ
# 1       ライズ
# 2     ヴォクシー
# 3        ノア
# 4        ノア
# 5      シエンタ
# 6      クラウン
# 7      シエンタ
# 8     ヴォクシー
# 9        ノア
# 10     シエンタ
# 11     シエンタ
# 12        -
# 13      アクア
# 14      NaN

# %% [markdown]
# ## tqnet (Y)

# %%
tqnet_df["text"] = tqnet_df["text"]\
    .str.replace("\n", ' ')\
    .str.replace("×", 'と')\
    .str.replace("&", 'と')\
    .str.replace("。", '')\
    .str.replace("→", ' ')\
    .str.replace("�", '')\
    .str.replace("販売店指摘）", '')\
    .str.replace(re.compile("（\w+）"), "")\
    .str.replace(re.compile("【第\w+報】"), '')

# %% [markdown]
# # テキストベクトル化(辞書なし検討) - Tokenizer活用
# ## X_label creation (768次元)

# %%
# tokenizerとmodelのload
model_name = 'bert-base-cased'
tokenizer = AutoTokenizer.from_pretrained(model_name)
# tokenizer = BertJapaneseTokenizer.from_pretrained(model_name)
model = BertModel.from_pretrained(model_name)
model = model.cuda()
# Out:
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertModel: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.bias', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %% [markdown]
# ## 日本語を英語に変換

# %%
d_t = []
d_v = []
for t_data in tqnet_df["text"]:
    translated_t = Translator().translate(t_data)
    d_t.append({
        "text": translated_t.text
    })
new_tqnet_df = pd.DataFrame(d_t)

for v_data in vocal_df["text"]:
    translated_v = Translator().translate(v_data)
    d_v.append({
        "text": translated_v.text
    })
new_vocal_df = pd.DataFrame(d_v)

# %%
len(new_vocal_df["text"])
# Out:
# 15

# %%
new_vocal_df.head(12)
# Out:
#                                                  text
# 0   It is difficult to close the door because the ...
# 1   When a shift knob is difficult to use near the...
# 2   The door panel on the passenger side and the g...
# 3   The engine sound when the engine sound is loud...
# 4   When the backdoor opening and closing operatio...
# 5   The driver's passenger seat It is difficult to...
# 6   Opening the trunk. The position of the switch ...
# 7   If you put the card in the meter where the car...
# 8   When a shift position that is likely to drop t...
# 9   The backdoor is heavy and it is difficult to o...
# 10  The backdoor that is much lighter than expecte...
# 11  It is difficult to grasp because it is difficu...

# %%
new_tqnet_df.head()
# Out:
#                                                 text
# 0  When I got into the driver's seat and tried to...
# 1  While driving, the sound of the engine feels l...
# 2  If there is a gap on the lower side of the shi...
# 3  The location of the switch that opens the trun...
# 4  The driver's seat and the passenger seat doors...

# %%
#各データの形式を整える
max_length = 256

x_dataset = []
# labels = []
for i in range(len(vocal_df)):
    # 記事から文章を抜き出し符号化を行う
    lines = new_vocal_df.iloc[i,0].splitlines()
    text = '\n'.join(lines)
    encoding = tokenizer(
        text,
        max_length = max_length,
        padding = 'max_length',
        truncation = True,
        return_tensors = 'pt'
        )
    encoding = {k: v.cuda() for k, v in encoding.items()}
    attention_mask = encoding['attention_mask']
    
    #文章ベクトルを計算
    with torch.no_grad():
        output = model(**encoding)
        last_hidden_state = output.last_hidden_state
        averaged_hidden_state =(last_hidden_state*attention_mask.unsqueeze(-1)).sum(1)/attention_mask.sum(1,keepdim=True) 
        
    #文章ベクトルとラベルを追加
    x_dataset.append(averaged_hidden_state[0].cpu().numpy())
    # label = vocal_df.iloc[i,1]
    # labels.append(label)

#ベクトルとラベルをnumpy.ndarrayにする
x_dataset = np.vstack(x_dataset)
# labels = np.array(labels)

# %% [markdown]
# ## Y_label creation

# %%
max_length = 256

y_dataset = []
for i in range(len(tqnet_df)):
    # 記事から文章を抜き出し符号化を行う
    lines = new_tqnet_df.iloc[i,0].splitlines()
    text = '\n'.join(lines)
    encoding = tokenizer(
        text,
        max_length = max_length,
        padding = 'max_length',
        truncation = True,
        return_tensors = 'pt'
        )
    encoding = {k: v.cuda() for k, v in encoding.items()}
    attention_mask = encoding['attention_mask']
    
    #文章ベクトルを計算
    with torch.no_grad():
        output = model(**encoding)
        last_hidden_state = output.last_hidden_state
        averaged_hidden_state =(last_hidden_state*attention_mask.unsqueeze(-1)).sum(1)/attention_mask.sum(1,keepdim=True) 
        
    #文章ベクトルとラベルを追加
    y_dataset.append(averaged_hidden_state[0].cpu().numpy())

#ベクトルとラベルをnumpy.ndarrayにする
y_dataset = np.vstack(y_dataset)

# %% [markdown]
# # テキストのベクトル化(model)

# %%
print(x_dataset.shape)
print(y_dataset.shape)
# Out:
# (15, 768)
# (8, 768)

# %%
import sklearn
data = sklearn.metrics.pairwise.cosine_similarity(x_dataset,y_dataset)

# %%
df = pd.DataFrame(data)

# %%
df.columns = ["Frドア重い", "加速音大きい", "シフト隙間", "SW場所不明確", "ドア重い", "new", "new+1", "new-1"]

# %%
df["Vocal/TQ-NET"] = [
    "Frドア重い", 
    "シフト使用性", 
    "グローブボックス位置", 
    "加速音大きい", 
    "バックドア操作", 
    "Frドア開閉し難い", 
    "SW場所不明確", 
    "メータ隙間", 
    "シフト隙間", 
    "バックドア重い",
    "バックドア軽い",
    "Frドア操作性",
    "スーパー外れ値",
    "マルチメディア関係",
    "Frドア重い(少な目)"
]

# %%
# first_column = df.pop("Vocal/TQ-NET")
# df.insert(0,"Vocal / TQ-NET",first_column)
df
# Out:
#       Frドア重い    加速音大きい     シフト隙間   SW場所不明確      ドア重い       new     new+1  \
# 0   0.910138  0.843165  0.865729  0.865214  0.923575  1.000000  1.000000
# 1   0.891290  0.883249  0.933996  0.894736  0.906452  0.864343  0.864343
# 2   0.918359  0.854998  0.929188  0.877602  0.926610  0.893869  0.893869
# 3   0.809757  0.899804  0.837084  0.825127  0.843486  0.810860  0.810860
# 4   0.900627  0.879891  0.918031  0.901687  0.911724  0.884457  0.884457
# 5   0.925488  0.868314  0.901501  0.890440  0.943052  0.937123  0.937123
# 6   0.875126  0.856590  0.872588  0.936097  0.874858  0.869650  0.869650
# 7   0.890542  0.840736  0.918781  0.887858  0.892640  0.845400  0.845400
# 8   0.846455  0.851058  0.910070  0.859277  0.896344  0.828202  0.828202
# 9   0.897792  0.857118  0.906617  0.888839  0.913156  0.878002  0.878002
# 10  0.870321  0.855345  0.877618  0.870288  0.891172  0.843702  0.843702
# 11  0.916598  0.849694  0.906490  0.905855  0.924129  0.930185  0.930185
# 12  0.372288  0.450737  0.387358  0.437054  0.389587  0.413526  0.413526
# 13  0.872368  0.853797  0.940317  0.856907  0.880015  0.825839  0.825839
# 14  0.917508  0.878372  0.901720  0.895232  0.936865  0.924134  0.924134
#
#        new-1 Vocal/TQ-NET
# 0   0.965061       Frドア重い
# 1   0.838204       シフト使用性
# 2   0.873375   グローブボックス位置
# 3   0.798735       加速音大きい
# 4   0.849258      バックドア操作
# 5   0.911243    Frドア開閉し難い
# 6   0.843431      SW場所不明確
# 7   0.823330        メータ隙間
# 8   0.817588        シフト隙間
# 9   0.845101      バックドア重い
# 10  0.836420      バックドア軽い
# 11  0.888521      Frドア操作性
# 12  0.424872      スーパー外れ値
# 13  0.818634    マルチメディア関係
# 14  0.904591  Frドア重い(少な目)

# %%
df.style.background_gradient()
# Out:
# <style type="text/css">
# #T_372c6_row0_col0, #T_372c6_row2_col4 {
#   background-color: #023f64;
#   color: #f1f1f1;
# }
# #T_372c6_row0_col1 {
#   background-color: #045a8d;
#   color: #f1f1f1;
# }
# #T_372c6_row0_col2 {
#   background-color: #045b8f;
#   color: #f1f1f1;
# }
# #T_372c6_row0_col3, #T_372c6_row8_col0, #T_372c6_row11_col7 {
#   background-color: #045d92;
#   color: #f1f1f1;
# }
# #T_372c6_row0_col4, #T_372c6_row1_col1, #T_372c6_row7_col2 {
#   background-color: #034267;
#   color: #f1f1f1;
# }
# #T_372c6_row0_col5, #T_372c6_row0_col6, #T_372c6_row0_col7, #T_372c6_row3_col1, #T_372c6_row5_col0, #T_372c6_row5_col4, #T_372c6_row6_col3, #T_372c6_row13_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_372c6_row1_col0, #T_372c6_row9_col2, #T_372c6_row11_col2, #T_372c6_row11_col3 {
#   background-color: #034871;
#   color: #f1f1f1;
# }
# #T_372c6_row1_col2, #T_372c6_row14_col4 {
#   background-color: #023a5b;
#   color: #f1f1f1;
# }
# #T_372c6_row1_col3, #T_372c6_row8_col4 {
#   background-color: #034e7b;
#   color: #f1f1f1;
# }
# #T_372c6_row1_col4, #T_372c6_row7_col0 {
#   background-color: #034973;
#   color: #f1f1f1;
# }
# #T_372c6_row1_col5, #T_372c6_row1_col6 {
#   background-color: #056dab;
#   color: #f1f1f1;
# }
# #T_372c6_row1_col7, #T_372c6_row10_col7 {
#   background-color: #056dac;
#   color: #f1f1f1;
# }
# #T_372c6_row2_col0, #T_372c6_row14_col0 {
#   background-color: #023b5d;
#   color: #f1f1f1;
# }
# #T_372c6_row2_col1, #T_372c6_row5_col7, #T_372c6_row10_col0, #T_372c6_row10_col1 {
#   background-color: #045382;
#   color: #f1f1f1;
# }
# #T_372c6_row2_col2 {
#   background-color: #023d60;
#   color: #f1f1f1;
# }
# #T_372c6_row2_col3, #T_372c6_row11_col5, #T_372c6_row11_col6 {
#   background-color: #04588a;
#   color: #f1f1f1;
# }
# #T_372c6_row2_col5, #T_372c6_row2_col6, #T_372c6_row3_col4 {
#   background-color: #04649d;
#   color: #f1f1f1;
# }
# #T_372c6_row2_col7 {
#   background-color: #046299;
#   color: #f1f1f1;
# }
# #T_372c6_row3_col0, #T_372c6_row9_col5, #T_372c6_row9_col6 {
#   background-color: #0569a4;
#   color: #f1f1f1;
# }
# #T_372c6_row3_col2 {
#   background-color: #04649e;
#   color: #f1f1f1;
# }
# #T_372c6_row3_col3, #T_372c6_row6_col5, #T_372c6_row6_col6, #T_372c6_row9_col7 {
#   background-color: #056ba7;
#   color: #f1f1f1;
# }
# #T_372c6_row3_col5, #T_372c6_row3_col6 {
#   background-color: #2182b9;
#   color: #f1f1f1;
# }
# #T_372c6_row3_col7 {
#   background-color: #1b7eb7;
#   color: #f1f1f1;
# }
# #T_372c6_row4_col0, #T_372c6_row4_col1 {
#   background-color: #03446a;
#   color: #f1f1f1;
# }
# #T_372c6_row4_col2 {
#   background-color: #034369;
#   color: #f1f1f1;
# }
# #T_372c6_row4_col3, #T_372c6_row5_col1, #T_372c6_row5_col2, #T_372c6_row14_col2 {
#   background-color: #034a74;
#   color: #f1f1f1;
# }
# #T_372c6_row4_col4, #T_372c6_row8_col2 {
#   background-color: #03476f;
#   color: #f1f1f1;
# }
# #T_372c6_row4_col5, #T_372c6_row4_col6 {
#   background-color: #0567a1;
#   color: #f1f1f1;
# }
# #T_372c6_row4_col7 {
#   background-color: #0569a5;
#   color: #f1f1f1;
# }
# #T_372c6_row5_col3, #T_372c6_row6_col0, #T_372c6_row7_col4, #T_372c6_row10_col4 {
#   background-color: #03517e;
#   color: #f1f1f1;
# }
# #T_372c6_row5_col5, #T_372c6_row5_col6, #T_372c6_row8_col1 {
#   background-color: #045585;
#   color: #f1f1f1;
# }
# #T_372c6_row6_col1, #T_372c6_row7_col3, #T_372c6_row9_col1, #T_372c6_row9_col3, #T_372c6_row13_col0 {
#   background-color: #045280;
#   color: #f1f1f1;
# }
# #T_372c6_row6_col2, #T_372c6_row6_col4 {
#   background-color: #04598c;
#   color: #f1f1f1;
# }
# #T_372c6_row6_col7 {
#   background-color: #056ba9;
#   color: #f1f1f1;
# }
# #T_372c6_row7_col1, #T_372c6_row10_col3, #T_372c6_row14_col5, #T_372c6_row14_col6 {
#   background-color: #045b8e;
#   color: #f1f1f1;
# }
# #T_372c6_row7_col5, #T_372c6_row7_col6, #T_372c6_row7_col7 {
#   background-color: #0a73b2;
#   color: #f1f1f1;
# }
# #T_372c6_row8_col3 {
#   background-color: #045f95;
#   color: #f1f1f1;
# }
# #T_372c6_row8_col5, #T_372c6_row8_col6 {
#   background-color: #157ab5;
#   color: #f1f1f1;
# }
# #T_372c6_row8_col7, #T_372c6_row13_col7 {
#   background-color: #0d75b3;
#   color: #f1f1f1;
# }
# #T_372c6_row9_col0, #T_372c6_row14_col1 {
#   background-color: #03456c;
#   color: #f1f1f1;
# }
# #T_372c6_row9_col4 {
#   background-color: #03466e;
#   color: #f1f1f1;
# }
# #T_372c6_row10_col2, #T_372c6_row13_col4 {
#   background-color: #045788;
#   color: #f1f1f1;
# }
# #T_372c6_row10_col5, #T_372c6_row10_col6 {
#   background-color: #0c74b2;
#   color: #f1f1f1;
# }
# #T_372c6_row11_col0 {
#   background-color: #023c5f;
#   color: #f1f1f1;
# }
# #T_372c6_row11_col1, #T_372c6_row14_col7 {
#   background-color: #045687;
#   color: #f1f1f1;
# }
# #T_372c6_row11_col4 {
#   background-color: #034165;
#   color: #f1f1f1;
# }
# #T_372c6_row12_col0, #T_372c6_row12_col1, #T_372c6_row12_col2, #T_372c6_row12_col3, #T_372c6_row12_col4, #T_372c6_row12_col5, #T_372c6_row12_col6, #T_372c6_row12_col7 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_372c6_row13_col1 {
#   background-color: #045483;
#   color: #f1f1f1;
# }
# #T_372c6_row13_col3 {
#   background-color: #046096;
#   color: #f1f1f1;
# }
# #T_372c6_row13_col5, #T_372c6_row13_col6 {
#   background-color: #187cb6;
#   color: #f1f1f1;
# }
# #T_372c6_row14_col3 {
#   background-color: #034d79;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_372c6_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Frドア重い</th>
#       <th class="col_heading level0 col1" >加速音大きい</th>
#       <th class="col_heading level0 col2" >シフト隙間</th>
#       <th class="col_heading level0 col3" >SW場所不明確</th>
#       <th class="col_heading level0 col4" >ドア重い</th>
#       <th class="col_heading level0 col5" >new</th>
#       <th class="col_heading level0 col6" >new+1</th>
#       <th class="col_heading level0 col7" >new-1</th>
#       <th class="col_heading level0 col8" >Vocal/TQ-NET</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_372c6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_372c6_row0_col0" class="data row0 col0" >0.910138</td>
#       <td id="T_372c6_row0_col1" class="data row0 col1" >0.843165</td>
#       <td id="T_372c6_row0_col2" class="data row0 col2" >0.865729</td>
#       <td id="T_372c6_row0_col3" class="data row0 col3" >0.865214</td>
#       <td id="T_372c6_row0_col4" class="data row0 col4" >0.923575</td>
#       <td id="T_372c6_row0_col5" class="data row0 col5" >1.000000</td>
#       <td id="T_372c6_row0_col6" class="data row0 col6" >1.000000</td>
#       <td id="T_372c6_row0_col7" class="data row0 col7" >0.965061</td>
#       <td id="T_372c6_row0_col8" class="data row0 col8" >Frドア重い</td>
#     </tr>
#     <tr>
#       <th id="T_372c6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_372c6_row1_col0" class="data row1 col0" >0.891290</td>
#       <td id="T_372c6_row1_col1" class="data row1 col1" >0.883249</td>
#       <td id="T_372c6_row1_col2" class="data row1 col2" >0.933996</td>
#       <td id="T_372c6_row1_col3" class="data row1 col3" >0.894736</td>
#       <td id="T_372c6_row1_col4" class="data row1 col4" >0.906452</td>
#       <td id="T_372c6_row1_col5" class="data row1 col5" >0.864343</td>
#       <td id="T_372c6_row1_col6" class="data row1 col6" >0.864343</td>
#       <td id="T_372c6_row1_col7" class="data row1 col7" >0.838204</td>
#       <td id="T_372c6_row1_col8" class="data row1 col8" >シフト使用性</td>
#     </tr>
#     <tr>
#       <th id="T_372c6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_372c6_row2_col0" class="data row2 col0" >0.918359</td>
#       <td id="T_372c6_row2_col1" class="data row2 col1" >0.854998</td>
#       <td id="T_372c6_row2_col2" class="data row2 col2" >0.929188</td>
#       <td id="T_372c6_row2_col3" class="data row2 col3" >0.877602</td>
#       <td id="T_372c6_row2_col4" class="data row2 col4" >0.926610</td>
#       <td id="T_372c6_row2_col5" class="data row2 col5" >0.893869</td>
#       <td id="T_372c6_row2_col6" class="data row2 col6" >0.893869</td>
#       <td id="T_372c6_row2_col7" class="data row2 col7" >0.873375</td>
#       <td id="T_372c6_row2_col8" class="data row2 col8" >グローブボックス位置</td>
#     </tr>
#     <tr>
#       <th id="T_372c6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_372c6_row3_col0" class="data row3 col0" >0.809757</td>
#       <td id="T
